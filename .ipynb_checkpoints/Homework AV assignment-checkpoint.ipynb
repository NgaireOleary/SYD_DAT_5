# %%
# %matplotlib inline
import pandas
import matplotlib.pyplot
import sklearn.linear_model

# %%
av_report = pandas.read_excel('../SYD_DAT_5/data/Report_H02_2016-07-07_12-47-05.xlsx')

# %%
av_report
# Out:
#     Period of bookings: Unnamed: 1           Unnamed: 2  \
# 0    Operations Centre:        NaN                  NaN
# 1             Category:        NaN                  NaN
# 2          Subcategory:        NaN                  NaN
# 3           Asset Type:        NaN                  NaN
# 4         Extracted on:        NaN                  NaN
# 5                   NaN        NaN                  NaN
# 6                  C_ID   C_Status             Category
# 7                     1          1                Audio
# 8                     1          1                Audio
# 9                     1          1                Audio
# 10                    1          1                Audio
# 11                    1          1                Audio
# 12                    1          1                Audio
# 13                    1          1                Audio
# 14                    1          1                Audio
# 15                    1          1                Audio
# ...

# %%
#changing column names
av_report.rename(columns={'Unnamed: 2':'Category'}, inplace=True)
av_report.rename(columns={'Unnamed: 6':'Subcategory'}, inplace=True)
av_report.rename(columns={'Unnamed: 7':'Subcategory_total'}, inplace=True)
av_report.rename(columns={'Unnamed: 10':'Asset_Type'}, inplace=True)
av_report.rename(columns={'Unnamed: 11':'Asset_bookings'}, inplace=True)

# %%
av_report
# Out:
#     Period of bookings: Unnamed: 1             Category  \
# 0    Operations Centre:        NaN                  NaN
# 1             Category:        NaN                  NaN
# 2          Subcategory:        NaN                  NaN
# 3           Asset Type:        NaN                  NaN
# 4         Extracted on:        NaN                  NaN
# 5                   NaN        NaN                  NaN
# 6                  C_ID   C_Status             Category
# 7                     1          1                Audio
# 8                     1          1                Audio
# 9                     1          1                Audio
# 10                    1          1                Audio
# 11                    1          1                Audio
# 12                    1          1                Audio
# 13                    1          1                Audio
# 14                    1          1                Audio
# 15                    1          1                Audio
# ...

# %%
av_report.describe()
# Out:
#         Period of bookings:  Unnamed: 1 Category  \
# count                   119         114      114
# unique                   17           2       12
# top                       1           1    Audio
# freq                     85         113       85
#
#         from 01-07-2015 to 01-07-2016  Unnamed: 4  Unnamed: 5  \
# count                             119         114         114
# unique                             14          33           2
# top                              2579          35           1
# freq                               85          63         113
#
#                 Subcategory  Subcategory_total  Unnamed: 8  Unnamed: 9  \
# count                   114                114         114         114
# unique                   33                 27         114           7
# top     Mic - Room Specific               1478          56           1
# freq                     63                 63           1          78
#
#                 Asset_Type  Asset_bookings
# ...

# %%
av_report.Asset_Type
# Out:
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                            Asset Type
# 7                  Audio down converter
# 8           Mixing Console - 12 Channel
# 9            Mixing Console - 4 Channel
# 10                   Portable CD player
# 11                Medium Active Speaker
# 12                 Small Active Speaker
# 13                           CB01-04-06
# 14                          CB02-03-02A
# 15                           CB02-03-17
# 16                           CB02-04-10
# 17                           CB02-04-11
# 18                           CB02-04-13
# 19                           CB02-04-23
# 20                           CB02-04-29
# 21                           CB02-05-33
# 22                          CB02-07-110
# ...

# %%
asset_use = av_report[['Subcategory', 'Subcategory_total']]
asset_use
# Out:
#                      Subcategory  Subcategory_total
# 0                            NaN                NaN
# 1                            NaN                NaN
# 2                            NaN                NaN
# 3                            NaN                NaN
# 4                            NaN                NaN
# 5                            NaN                NaN
# 6                    Subcategory  Subcategory Total
# 7    Audio Amplifier / Processor                  2
# 8           Audio Mixing Console                 24
# 9           Audio Mixing Console                 24
# 10                     CD Player                  1
# 11                   Loudspeaker                 80
# 12                   Loudspeaker                 80
# 13           Mic - Room Specific               1478
# 14           Mic - Room Specific               1478
# 15           Mic - Room Specific               1478
# 16           Mic - Room Specific               1478
# ...

# %%
#remove the DVD/VHS line as pandas is not dealing with the forward slash
#remove junk lines
asset_use_clean = asset_use.ix[119:]
asset_use_clean = asset_use.ix[8:]
asset_use_clean
# Out:
#               Subcategory Subcategory_total
# 8    Audio Mixing Console                24
# 9    Audio Mixing Console                24
# 10              CD Player                 1
# 11            Loudspeaker                80
# 12            Loudspeaker                80
# 13    Mic - Room Specific              1478
# 14    Mic - Room Specific              1478
# 15    Mic - Room Specific              1478
# 16    Mic - Room Specific              1478
# 17    Mic - Room Specific              1478
# 18    Mic - Room Specific              1478
# 19    Mic - Room Specific              1478
# 20    Mic - Room Specific              1478
# 21    Mic - Room Specific              1478
# 22    Mic - Room Specific              1478
# 23    Mic - Room Specific              1478
# 24    Mic - Room Specific              1478
# 25    Mic - Room Specific              1478
# 26    Mic - Room Specific              1478
# 27    Mic - Room Specific              1478
# ...

# %%
asset_use_clean.head()
# Out:
#              Subcategory Subcategory_total
# 8   Audio Mixing Console                24
# 9   Audio Mixing Console                24
# 10             CD Player                 1
# 11           Loudspeaker                80
# 12           Loudspeaker                80

# %%
asset_use_clean.mean()
# Out:
# Series([], dtype: float64)

# %%
asset_use_clean.max()
# Out:
# Subcategory          Wireless Speaker
# Subcategory_total                1478
# dtype: object

# %%
matplotlib.pyplot.scatter(asset_use_clean.Subcategory, asset_use_clean.Subcategory_total)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-ed8cd021f685> in <module>()
# ----> 1 matplotlib.pyplot.scatter(asset_use_clean.Subcategory, asset_use_clean.Subcategory_total)
#
# /Users/ngaireoleary/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3249                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3250                          linewidths=linewidths, verts=verts,
# -> 3251                          edgecolors=edgecolors, data=data, **kwargs)
#    3252     finally:
#    3253         ax.hold(washold)
#
# /Users/ngaireoleary/anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
# ...
